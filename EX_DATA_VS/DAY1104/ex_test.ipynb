# %% [markdown]
# ### 【 데이터 시각화 】
# - 데이터셋 : iris.csv
# - 해결문제 : 품종별 시각화에 적합한 특성/속성/컬럼 선정
# - 출력결과 : 선정된 특성을 기반으로 품종 분류한 것 시각화

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Data/iris.csv')
df.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df = df.set_index('variety')
df
# Out:
#            sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa              5.1          3.5           1.4          0.2
# Setosa              4.9          3.0           1.4          0.2
# Setosa              4.7          3.2           1.3          0.2
# Setosa              4.6          3.1           1.5          0.2
# Setosa              5.0          3.6           1.4          0.2
# ...                 ...          ...           ...          ...
# Virginica           6.7          3.0           5.2          2.3
# Virginica           6.3          2.5           5.0          1.9
# Virginica           6.5          3.0           5.2          2.0
# Virginica           6.2          3.4           5.4          2.3
# Virginica           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
plt.plot(df.index, df.values)
# Out:
# [<matplotlib.lines.Line2D at 0x1e0977bf550>,
#  <matplotlib.lines.Line2D at 0x1e09783da10>,
#  <matplotlib.lines.Line2D at 0x1e09783dd10>,
#  <matplotlib.lines.Line2D at 0x1e09783e010>]

# %%
line = plt.plot(df['sepal.length'], df['sepal.width'])
