# %% [markdown]
# ####  【 ndarray 원소 다루기 】
# - 인덱싱
#     * 변수명[인덱스] / 변수명[행인덱스][열인덱스]
#
# - 슬라이싱
#     * 변수명[시작인덱스   : 끝인덱스  : 간격]
#     * 변수명[행시작인덱스 : 행끝인덱스 : 간격, 열시작인덱스 : 열끝인덱스 : 간격]
#     * 범위 : 시작인덱스<= ~ < 끝인덱스

# %%
## 모듈 로딩
import numpy as np
