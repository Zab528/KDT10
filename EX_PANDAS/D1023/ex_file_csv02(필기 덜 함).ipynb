# %% [markdown]
# ### 【 파일 입력과 출력 】
# - pandas.read_XXX() : 다양한 포맷의 파일 ==> DataFrame으로 변환
#     * 파일 종류에 따라서 변환 시 설정 필요함!
#
# - pandas.to_XXX() : DataFrame ==> 다양한 포맷 str 또는 file 변환

# %%
## [1] 모듈 로딩
import pandas as pd         ## 데이터분석 모델
import os                   ## 파이썬 내장 모듈, 경로, 폴더, 시스템 관련 처리 모듈
import glob

# %%
## [2] 데이터 준비 - 파일 리스트 추출
DATA_DIR = '../Data'

## 폴더내 파일명을 리스트에 담아서 반환
FILE_LIST = os.listdir(DATA_DIR)
print(FILE_LIST)

## 파일경로+파일명
FILE_NAME = f'{DATA_DIR}/{FILE_LIST[1]}'

print( FILE_NAME )
# Out:
# ['book.xml', 'data01.csv', 'data02.csv', 'hello.html', 'no_comma.csv', 'no_head.csv', 'test.csv', 'test.json', 'test.txt', 'test2.csv', 'titanic.csv', 'titanic_train.csv']
# ../Data/data01.csv

# %%
## [2] 데이터 준비 - 파일 리스트 추출

## 폴더내 파일명을 리스트에 담아서 반환
## * 의미 : 모든 것
## *.* 의미 : 모든파일명.모든확장
FILE_LIST = glob.glob(f'{DATA_DIR}/*.*')
print(FILE_LIST)

FILE_LIST = glob.glob(f'{DATA_DIR}/*.csv')
print(FILE_LIST)

FILE_LIST = glob.glob(f'{DATA_DIR}/*.xml')
print(FILE_LIST)

##-> i로 시작하고 확장자가 csv인 파일리스트
FILE_LIST = glob.glob(f'{DATA_DIR}/i*.csv')
print(FILE_LIST)

FILE_NAME = FILE_LIST[0]
# Out:
# ['../Data\\book.xml', '../Data\\data01.csv', '../Data\\data02.csv', '../Data\\hello.html', '../Data\\housing.csv', '../Data\\iris.csv', '../Data\\no_comma.csv', '../Data\\no_head.csv', '../Data\\test.csv', '../Data\\test.json', '../Data\\test.txt', '../Data\\test2.csv', '../Data\\titanic.csv', '../Data\\titanic_train.csv']
# ['../Data\\data01.csv', '../Data\\data02.csv', '../Data\\housing.csv', '../Data\\iris.csv', '../Data\\no_comma.csv', '../Data\\no_head.csv', '../Data\\test.csv', '../Data\\test2.csv', '../Data\\titanic.csv', '../Data\\titanic_train.csv']
# ['../Data\\book.xml']
# ['../Data\\iris.csv']

# %%
## [3] CSV 파일 ==> DataFrame으로 변환

## 앞부분 일부 데이터 제거하고 가져오기
csvDF = pd.read_csv(FILE_NAME, skipfooter=50, header=None)

## 출력
csvDF
# Out:
# C:\Users\KDT\AppData\Local\Temp\ipykernel_1488\1578776188.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   csvDF = pd.read_csv(FILE_NAME, skipfooter=50, header=None)
#                 0            1             2            3           4
# 0    sepal.length  sepal.width  petal.length  petal.width     variety
# 1             5.1          3.5           1.4           .2      Setosa
# 2             4.9            3           1.4           .2      Setosa
# 3             4.7          3.2           1.3           .2      Setosa
# 4             4.6          3.1           1.5           .2      Setosa
# ..            ...          ...           ...          ...         ...
# 96            5.7            3           4.2          1.2  Versicolor
# 97            5.7          2.9           4.2          1.3  Versicolor
# 98            6.2          2.9           4.3          1.3  Versicolor
# 99            5.1          2.5             3          1.1  Versicolor
# 100           5.7          2.8           4.1          1.3  Versicolor
#
# [101 rows x 5 columns]

# %%
## [4] CSV 파일 ==> DataFrame으로 변환

## 끝부분 일부 데이터 제거하고 가져오기 : skipfooter = 50
##                   추가로 엔진 설정  engine='python'
csvDF = pd.read_csv(FILE_NAME, skipfooter=50, engine='python')

## 출력
csvDF
# Out:
# Empty DataFrame
# Columns: [11, 20, 3.4]
# Index: []

# %%
## [5] 데이터 준비 - 특정 컬럼을 행 인덱스 설정
FILE_NAME = f'{DATA_DIR}/test2.csv'

## 날짜/시간 str로 object 타입 ==> datetime64[ns] 타입 변환
csvDF = pd.read_csv(FILE_NAME, sep=' ', parse_dates=['DATE'])

print(csvDF, csvDF.dtypes, sep='\n\n')
