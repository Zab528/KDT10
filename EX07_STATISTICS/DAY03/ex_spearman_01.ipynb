# %% [markdown]
# #### 【 Spearman Rank Coefficient 】
# - 연속형 데이터, 선형 또는 비선형 단조 강도 측정
# - 단조 : 전체적으로 데이터의 증가 또는 감소
# - 정규분포 X, 이상치 영향 약. 비선형도 가능

# %%
## =================================================
## 모듈 로딩
## =================================================
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, spearmanr
import koreanize_matplotlib
