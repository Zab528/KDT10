# %% [markdown]
# ### 【일반·절사·가중평균 】

# %%
## 모듈 로딩
import numpy as np
import pandas as pd

# %%
## 데이터 
data    = np.array([50,60,70,80,90,1000])   ## 마지막 1000은 극단값이라고 생각
weights = np.array([1,1,1,1,1,2])           ## 1000점에 더 큰 가중치
