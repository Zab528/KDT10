# %% [markdown]
# ##### 【기본 개념 이해 중심】<hr>

# %% [markdown]
# 1. X ~ B(n, p) 기대값은?
# ① np
# ② n/p
# ③ n(1−p)
# ④ p(1−p)
#
# - 답 : 1
# - 내 풀이 : 이항분포의 기대값 공식은 E[X] = np이다.

# %% [markdown]
# 2. 정규분포의 대표적인 특징은?
# ① 왼쪽으로만 치우친 분포
# ② 평균 = 중앙값 = 최빈값
# ③ 오른쪽 꼬리가 더 긴 분포
# ④ 이산형이다.
#
# - 답 : 2번
# - 내 풀이 : 정규분포는 평균을 기준으로 좌우로 대칭이며 평균과 중앙값, 최빈값이 같다.

# %% [markdown]
# 3. 표준정규분포의 평균과 표준편차는?
# ① (0, 1)
# ② (1, 0)
# ③ (1, 1)
# ④ (0, 0)
#
# - 답 : 1번
# - 내 풀이 : 표준정규분포는 정규분포를 z-score로 표준화한 것으로, 평균이 0이고 표준편차가 1이다.

# %% [markdown]
# 4. 모집단 평균 추정을 하는 경우, 신뢰구간이 넓어진다는 것은?
# ① 표본이 증가해서 불확실성이 줄었다.
# ② 표본이 작거나 신뢰수준이 높다.
# ③ 모집단이 정규분포가 아니다.
# ④ 표본분산이 0이다.
#
# - 답 : 2번
# - 내 풀이 : 표본이 작거나 신뢰수준을 높일수록 불확실성을 보완하기 위해 구간을 더 넓게 잡는다.

# %% [markdown]
# 5. p-value가 매우 작으면 의미하는 것은?
# ① 귀무가설을 기각하기 어렵다.
# ② 귀무가설을 지지한다.
# ③ 귀무가설이 사실일 가능성이 낮다.
# ④ 표본이 항상 정규분포를 따른다.
#
# - 답 : 3번
# - 내 풀이 : p-value는 현재처럼 극단적인 값이 나올 확률을 의미하므로, p-value가 작으면 귀무가설을 기각한다.

# %% [markdown]
# 6. 정규분포가 왜 통계학에서 중요한지 중심극한정리 관점에서 설명하시오.
#
# - 내 풀이 : 중심극한정리에 의하면 표본크기가 충분히 크면 표본평균의 분포가 정규분포에 가까워지는데, 그러면 통계적 추론을 수행할 때 정규분포를 기반으로 한 다양한 방법을 사용할 수 있다.

# %% [markdown]
# 7. 표본과 모집단의 차이를 간단히 설명하시오.
#
# - 내 풀이 : 모집단은 전체, 표본은 그 중에서 추려낸 집단이다.

# %% [markdown]
# 8. 95% 신뢰구간의 의미를 설명하시오.
#
# - 내 풀이 : 같은 방법으로 표본을 반복 추출해 신뢰구간을 만들면 그 구간들 중 약 95프로가 실제 모집단 평균을 포함하게 된다는 의미이다.

# %% [markdown]
# 9. t-분포가 정규분포보다 꼬리가 두꺼운 이유는?
# ① 소표본에서는 불확실성이 커서
# ② 표본이 무한히 크기 때문에
# ③ 이산형 분포여서
# ④ 평균이 0이 아니어서
#
# - 답 : 1번
# - 내 풀이 : 소표본을 추정할 때 사용되기 때문에 표본분산의 불확실성이 커서 극단값이 더 나올 가능성을 반영해야 한다.

# %% [markdown]
# 11. 카이제곱분포의 대표적인 사용 용도는?
# ① 평균 비교
# ② 독립성 검정
# ③ 비율 검정
# ④ 표준편차 비교
#
# - 답 : 2번
# - 내 풀이 : 카이제곱분포는 범주형 변수 간의 관계를 분석할 때 사용하며 독립성 검정과 적합성 검정을 할 때 주로 사용한다.

# %% [markdown]
# 12. 1종 오류(Type I error)의 의미는?
# ① 참인 귀무가설을 기각
# ② 거짓인 귀무가설을 기각
# ③ 참인 대립가설을 기각
# ④ 표본 오차가 0인 경우
#
# - 답 : 1번
# - 내 풀이 : 1종 오류란 참임에도 불구하고 이를 잘못 기각하는 오류를 의미한다.

# %% [markdown]
# 13. 신뢰수준을 높이면 신뢰구간은 어떻게 되는가?
# ① 더 좁아진다.
# ② 변하지 않는다.
# ③ 더 넓어진다.
# ④ 무의미해진다.
#
# - 답 : 3번
# - 내 풀이 : 신뢰수준을 높이면 그만큼 신뢰구간을 넓혀야 모집답 평균을 찾을 확률이 올라간다.

# %% [markdown]
# 14. 중심극한정리(CLT)가 추론통계의 기반인 이유를 설명하시오.
#
# - 내 풀이 : 표본 개수를 늘려서 정규분포에 가깝게 하여 정규분포를 이용한 신뢰구간과 가설검정 같은 추론 기법을 적용할 수 있게 해준다.

# %% [markdown]
# 15. X ~ N(μ, σ²)를 Z로 표준화하는 공식은?
# ① Z = X − μ
# ② Z = (X − μ)σ
# ③ Z = (X − μ)/σ
# ④ Z = μ − X / σ
#
# - 답 : 3번
# - 내 풀이 : 3번이 정규분포를 표준정규분포로 변환하는 공식이다.

# %% [markdown]
# 16. 정규분포에서 약 68%는 평균에서 몇 표준편차 이내에 있는가?
# ① ±1σ
# ② ±2σ
# ③ ±3σ
# ④ ±0.5σ
#
# - 답 : 1번
# - 내 풀이 : ±1σ는 68%, ±2σ는 95%, ±3σ는 99%이다.

# %% [markdown]
# 17. 어떤 정규분포의 확률밀도함수(f(x))는 높고 좁으며 뾰족하다. 이때 분산 σ²는?
# ① 매우 크다.
# ② 매우 작다.
# ③ 항상 1이다.
# ④ 알 수 없다.
#
# - 답 : 2번
# - 내 풀이 : 분산은 곡선의 퍼짐 정도를 의미하는데 분산이 작으면 분포가 좁고 뾰족하기 때문에 그래프가 높고 날카로운 형태이다.

# %% [markdown]
# 18. X ~ N(μ, σ²)에서 꼬리(tail) 확률이 더 중요한 분석은?
# ① 중간값 분석
# ② 이상치 판정
# ③ 산술평균 계산
# ④ 히스토그램 계산
#
# - 답 : 2번
# - 내 풀이 : 꼬리 확률이란 평균에서 아주 멀리 떨어진 극단값이 나올 확률이므로, 이런 극단값의 발생 여부를 판단하는 이상치 판정에서 중요하다.

# %% [markdown]
# 19. 어떤 문제를 맞출 확률이 일정한 상황에서,
# 학생이 8문제를 찍어서 풀었고 그중 3문제가 맞았다.
# 이때 한 문제를 맞출 성공확률 p의 추정값을 구하시오.
#
# - 답 : 3/8
# - 내 풀이 : p의 추정값 => 성공한 횟수/전체 시행 횟수이므로 3/8이다

# %% [markdown]
# 20. 한 카페에 손님이 평균적으로 1분당 2명 방문한다고 한다.
#     이 카페에 1분 동안 손님이 0명 방문할 확률을 푸아송분포로 구하시오.
# 단.from scipy.stats import poisson
#
# - 답 : 0.1353352832366127
# - 내 풀이 : 1분당 평균 2명, 1분 동안 0명 방문 확률

# %%
## 20번 코드
from scipy.stats import poisson
prob = poisson.pmf(0, 2)
print(prob)
# Out:
# 0.1353352832366127
