# %% [markdown]
# ##### 데이터 분석 기초 통계 시험지 (20문항)
#
# - 이론: 객관식/주관식 17문항
# - 실습: 데이터 전처리 + 시각화 3문항
# - 사용 가능 라이브러리: `pandas`, `numpy`, `matplotlib`, `scipy`
#
# ※ 실습 문제(Q18~Q20)는 **코드 셀에 직접 작성**하세요.

# %%
# ======================================================================
# ### Q1. (객관식)  
# 다음 중 데이터의 중심경향성을 나타내는 값이 아닌 것은?  
# ① 평균  ② 중앙값  ③ 최빈값  ④ 범위(Range)
# ======================================================================
'''
답 : 4번 (범위(Range))
'''
# Out:
# '\n답 : 4번 (범위(Range))\n'

# %%
# ======================================================================
# ### Q2. (주관식)  
# 아래 데이터의 평균을 계산하세요. 일반평균, 절사평균, 가중평균
# 가장 적합한 평균은 무엇이고 이유를 설명하세요.
# values = [12, 14, 13, 15, 14, 12, 600, 12, 15, 14, 700]
# ======================================================================
import pandas as pd

data = pd.Series([12, 14, 13, 15, 14, 12, 600, 12, 15, 14, 700])
print(f'일반평균 => {data.mean()}')

data2 = data.sort_values()[1:-1]
print(f'절삭평균 => {data2.mean()}')

weight = pd.Series([1, 1, 1, 1, 1, 1, 0.02, 1, 1, 1, 0.02])
data3 = data * weight
print(f'가중평균 => {data3.mean()}')

## 가장 적합한 평균 => 가중평균
## 이유 : 데이터 안에 600과 700이라는 이상치가 존재하기 때문에 이 이상치에 낮은 가중치를 주어 문제를 해결할 수 있다.
# Out:
# 일반평균 => 129.1818181818182
# 절삭평균 => 78.77777777777777
# 가중평균 => 13.363636363636363

# %%
# ======================================================================
# ### Q3. (객관식)  
# 이상치(Outlier)가 평균(mean)에 미치는 영향은?  
# ① 평균을 거의 변화시키지 않는다  
# ② 평균을 크게 왜곡할 수 있다  
# ③ 중앙값만 변화시키고 평균은 변하지 않는다  
# ④ 분산을 줄인다  
# ======================================================================
'''
답 : 2번
'''
# Out:
# '\n답 : 2번\n'

# %%
# ======================================================================
# ### Q4. (주관식)  
# 이상치 탐지를 위해 자주 사용하는 두 가지 방법을 쓰시오.  
# ======================================================================
'''
1. q1과 q3를 구해서 IQR를 구한 후 q1 - IQR*1.5보다 작거나 q3 + IQR*1.5보다 큰 값을 이상치로 찾아낸다.
2. Box-plot 그래프를 그려서 현재 데이터에 이상치가 얼마나 존재하는지 시각적으로 확인한다.
'''
# Out:
# '\n1. q1과 q3를 구해서 IQR를 구한 후 q1 - IQR*1.5보다 작거나 q3 + IQR*1.5보다 큰 값을 이상치로 찾아낸다.\n2. Box-plot 그래프를 그려서 현재 데이터에 이상치가 얼마나 존재하는지 시각적으로 확인한다.\n'

# %%
# ======================================================================
# ### Q5. (객관식)  
# 표본 분산 계산에서 n 대신 n−1을 사용하는 이유는?  
# ① 계산을 단순하게 하기 위해  
# ② 표본 평균을 사용함에 따라 발생하는 편향을 보정하기 위해  
# ③ 평균보다 작은 값이 많기 때문에  
# ④ 분산값을 줄이기 위해
# ======================================================================
'''
답 : 2번
'''
# Out:
# '\n답 : 2번\n'

# %%
# ======================================================================
# ### Q6. (주관식)  
# 로그 변환(log transform)을 사용하는 목적을 간단히 두 가지 쓰시오.
# ======================================================================
'''
1. 로그 변환을 통해 값끼리 차이가 크게 발생해도 변환을 통해 이를 줄일 수 있기 때문이다.
2. 로그 변환을 통해 분포를 더욱 정규분포에 가깝게 만들어 정규분포에서만 확인할 수 있는 것들을 적용시키기 위해서이다.
'''
# Out:
# '\n1. 로그 변환을 통해 값끼리 차이가 크게 발상해도 이를 줄일 수 있기 때문이다.\n2. 로그 변환을 통해 분포를 더욱 정규분포에 가깝게 만들어 정규분포에서만 사용할 수 있는 것들을 적용시키기 위해서이다.\n'

# %%
# ======================================================================
# ### Q7. (객관식)  
# 어떤 사건 A의 확률이 0.4, B의 확률이 0.5이고 두 사건이 독립일 때  
# P(A ∩ B)는?  
# ① 0.2  ② 0.4  ③ 0.6  ④ 0.9
# ======================================================================
'''
독립이면 교집합은 두 확률의 곱이므로 0.4*0.5 = 0.2
답 : 1번
'''
# Out:
# '\n독립이면 교집합은 두 확률의 곱이므로 0.4*0.5 = 0.2\n답 : 1번\n'

# %%
# ======================================================================
# ### Q8. (주관식)  
# 정규분포를 표준정규분포로 바꾸기 위한 변환식을 쓰시오.  
# 어떤 분석에서 모집단 평균 μ를 추정하기 위해 표본평균의 분포를 정규분포로 가정하고, 
# 아래와 같은 형태의 그래프가 주어졌다.
# -> 정규분포 곡선(center = 표본평균)
# -> 평균을 중심으로 좌우 대칭
# -> 양쪽 끝에서 잘린 형태로 95% 신뢰구간(Confidence Interval) 이 표시되어 있음

# 이 그래프를 바탕으로 다음 질문에 답하시오.
# 질문1) 신뢰구간(Confidence Interval) 이 의미하는 바를 설명하시오.
# 질문2) 신뢰도(Confidence Level)가 95%라는 의미를 서술하시오.
# 질문3) 신뢰도를 95%에서 99%로 높이면, 신뢰구간의 폭은 넓어지는가 좁아지는가? 
# ======================================================================
'''
- 정규분포를 표준정규분포로 바꾸기 위한 변환식을 쓰시오.
=> (X-뮤)/시그마

질문1) 신뢰구간(Confidence Interval) 이 의미하는 바를 설명하시오.
=> 데이터를 뽑았을 때 그 데이터가 나온다고 신뢰할 수 있는 구간
질문2) 신뢰도(Confidence Level)가 95%라는 의미를 서술하시오.
=> 100개의 데이터를 뽑으면 그중 95개의 데이터가 신뢰구간 안에 존재한다.
질문3) 신뢰도를 95%에서 99%로 높이면, 신뢰구간의 폭은 넓어지는가 좁아지는가?
=> 신뢰도를 높이면 신뢰구간을 넓혀야 하기 때문에 신뢰구간의 폭은 넓어진다.
'''
# Out:
# '\n- 정규분포를 표준정규분포로 바꾸기 위한 변환식을 쓰시오.\n=> (X-뮤)/시그마\n\n질문1) 신뢰구간(Confidence Interval) 이 의미하는 바를 설명하시오.\n=> 데이터를 뽑았을 때 그 데이터가 나온다고 신뢰할 수 있는 구간\n질문2) 신뢰도(Confidence Level)가 95%라는 의미를 서술하시오.\n=> 100개의 데이터를 뽑으면 그중 95개의 데이터가 신뢰구간 안에 존재한다.\n질문3) 신뢰도를 95%에서 99%로 높이면, 신뢰구간의 폭은 넓어지는가 좁아지는가?\n=> 신뢰도를 높이면 신뢰구간을 넓혀야 하기 때문에 신뢰구간의 폭은 넓어진다.\n'

# %%
# ======================================================================
# ### Q9. (객관식)  
# 다음 중 오른쪽 꼬리가 긴 분포(양의 왜도)를 가진 데이터의 예시로 적절한 것은?  
# ① 키(height)  
# ② 자동차 가격  
# ③ 시험 점수(정규분포 가정)  
# ④ 동전 10번 던졌을 때 앞면 개수
# ======================================================================
'''
답 : 2번
'''
# Out:
# '\n답 : 2번\n'

# %%
# ======================================================================
# ### Q10. (주관식)  
# 이항분포 Binomial(n=5, p=0.5)에서  "정확히 3번 성공할 확률"을 구하세요.
# scipy의 binom.pmf()함수 사용
# ======================================================================
from scipy.stats import binom
k = 3
n = 5
p = 0.5

result = binom.pmf(k, n, p)
print(result)
# Out:
# 0.31249999999999983

# %%
# ======================================================================
# ### Q11. (객관식)  
# 포아송 분포는 어떤 상황에서 잘 사용되는가?  
# ① 희귀한 사건의 발생 횟수  
# ② 연속적인 시간 측정  
# ③ 시험 점수 계산  
# ④ 평균 비교
# ======================================================================
'''
답 : 1번
'''
# Out:
# '\n답 : 1번\n'

# %%
# ======================================================================
# ### Q12. (주관식)  
# 데이터가 정규분포를 따르는지 여부를 확인하는 방법을 2가지 이상 서술하시오.
# - 시각화 방법
# - 기술통계적 방법 
# ======================================================================
'''
1. 왜도 계산하기 : 양의 왜도(왼쪽 치우침), 음의 왜도(오른쪽 치우침) 발생하는지
2. 첨도 계산하기 : 뾰족(첨도>0) 또는 평평(첨도<0)인지
3. Q-Q Plot 그리기 : 데이터가 45도의 직선과 근접하게 가고 휘어지거나 튀지 않는지 확인하기
4. 평균-중앙값-최빈값 비교하기 : 평균,중앙값,최빈값이 서로 비슷하거나 같은지 값을 비교한다.
'''
# Out:
# '\n1. 왜도 계산하기 : 양의 왜도(왼쪽 치우침), 음의 왜도(오른쪽 치우침) 발생하는지\n2. 첨도 계산하기 : 뾰족(첨도>0) 또는 평평(첨도<0)인지\n3. Q-Q Plot 그리기 : 데이터가 45도의 직선과 근접하게 가고 휘어지거나 튀지 않는지 확인하기\n4. 평균-중앙값-최빈값 비교하기 : 평균,중앙값,최빈값이 서로 비슷하거나 같은지 값을 비교한다.\n'

# %%
# ======================================================================
# ### Q13. (객관식)  
# p-value가 0.03일 때 올바른 해석은?  
# ① 귀무가설이 참일 확률이 3%  
# ② 귀무가설 하에서 관측된 결과가 나올 확률이 3%  
# ③ 대립가설이 참일 확률이 97%  
# ④ 실험이 잘못되었음을 의미
# ======================================================================
'''
답 : 2번
'''
# Out:
# '\n답 : 2번\n'

# %%
# ======================================================================
# ### Q14. (주관식)  
# 데이터 전처리 과정에서 다음 4단계가 왜 필요한지 간단히 설명하시오.
# -> 변수별 분포 확인
# -> 결측치 처리
# -> 이상치 탐지
# -> 변수 간 관계 분석(상관계수 또는 카이제곱)
# ======================================================================
'''
결론적으로는 데이터에서 원하는 결과값을 가장 잘 뽑아내기 위해서이다.
변수별 분포 확인을 통해 데이터끼리 분포가 멀리 떨어지지는 않는지 확인하고,
결측치 처리를 통해 결측치에 따른 데이터 부족이나 오차를 줄인다.
이상치 탐지를 통해서 결과값 도출에 방해되는 값이 없는지 확인하고
변수 간 관계 분석을 통해 어떤 변수끼리 가장 높은 관계를 가지는지 확인해본다.
'''
# Out:
# '\n결론적으로는 데이터에서 원하는 결과값을 가장 잘 뽑아내기 위해서이다.\n변수별 분포 확인을 통해 데이터끼리 분포가 멀리 떨어지지는 않는지 확인하고,\n결측치 처리를 통해 결측치에 따른 데이터 부족이나 오차를 줄인다.\n이상치 탐지를 통해서 결과값 도출에 방해되는 값이 없는지 확인하고\n변수 간 관계 분석을 통해 어떤 변수끼리 가장 높은 관계를 가지는지 확인해본다.\n'

# %%
# ======================================================================
# ### Q15. (객관식)  
# 두 집단의 평균 차이를 비교할 때 사용하는 검정은?  
# ① 카이제곱 독립성 검정  
# ② 독립표본 t-test  
# ③ 상관 분석  
# ④ 회귀분석만 가능하다
# ======================================================================
'''
답 : 4번
'''
# Out:
# '\n답 : 4번\n'

# %%
# ======================================================================
# ### Q16. (주관식)  
# 상관분석에서 다음 세 가지 상관계수가 사용된다:
# -> 피어슨 상관계수(Pearson r)
# -> 스피어맨 순위 상관계수(Spearman ρ)
# -> 켄달 순위 상관계수(Kendall τ)
# 각 상관계수의 특징, 적용 상황, 그리고 어떤 데이터(또는 관계 형태)에 적합한지를 
# 서술하시오.
# ======================================================================
'''
1. 피어슨 상관계수
특징 : 가장 기본적인 데이터, 선형 상관계수이며 이상치에 약함
적용 상황 : 이상치가 적거나 없고 선형 관계의 데이터가 주어졌을 때
적합한 데이터 : 선형 데이터

2. 스피어맨 순위 상관계수
특징 : 순위 기반 상관계수로 이상치에 강하다.
적용 상황 : 비선형 데이터가 주어졌을 때 적용 가능하다.
적합한 데이터 : 비선형 단조 데이터

3. 켄달 순위 상관계수
특징 : 순위 기반 상관계수로 이상치에 가장 강하다
적용 상황 : 비선형 데이터나 이상치가 있는 데이터가 주어졌을 때 적용 가능하다.
적합한 데이터 : 비선형 데이터
'''
# Out:
# '\n1. 피어슨 상관계수\n특징 : 가장 기본적인 데이터, 선형 상관계수이며 이상치에 약함\n적용 상황 : 이상치가 적거나 없고 선형 관계의 데이터가 주어졌을 때\n적합한 데이터 : 선형 데이터\n\n2. 스피어맨 순위 상관계수\n특징 : 순위 기반 상관계수로 이상치에 강하다.\n적용 상황 : 비선형 데이터가 주어졌을 때 적용 가능하다.\n적합한 데이터 : 비선형 단조 데이터\n\n3. 켄달 순위 상관계수\n특징 : 순위 기반 상관계수로 이상치에 가장 강하다\n적용 상황 : 비선형 데이터나 이상치가 있는 데이터가 주어졌을 때 적용 가능하다.\n적합한 데이터 : 비선형 데이터\n'

# %%
# ======================================================================
# ### Q17. (객관식)  
# 상관계수 r=0에 가까울수록 의미하는 것은?  
# ① 두 변수는 완전히 독립  
# ② 선형관계가 약함  
# ③ 비선형관계가 강함  
# ④ 인과성이 있다
# ======================================================================
'''
답 : 1번
'''
# Out:
# '\n답 : 1번\n'

# %%
# ======================================================================
# Q18. (실습 — 전처리 기초)  
# ======================================================================
# `titanic.csv`를 불러와 다음을 수행하시오.

# 1) Age 결측치를 중앙값으로 대체하고, 결과를 `df_age_filled`라는 DataFrame에 저장  
# 2) Fare 항목의 히스토그램을 그리시오  
# 3) Fare에서 이상치(상위 1%) 값의 개수를 계산하여 `q18_outlier_count` 변수에 저장  

# 아래 코드 셀에 작성하세요.

# %%
DATA_FILE = '../Exam/titanic.csv'
df = pd.read_csv(DATA_FILE)

# 1) Age 결측치를 중앙값으로 대체하고, 결과를 `df_age_filled`라는 DataFrame에 저장
m = df['Age'].median()
df_age_filled = df.copy()
df_age_filled['Age'] = df['Age'].fillna(m)

# %%
# 2) Fare 항목의 히스토그램을 그리시오
import matplotlib.pyplot as plt
import koreanize_matplotlib
plt.hist(df['Fare'], bins=30)
plt.title('Fare 항목 히스토그램')
# Out:
# Text(0.5, 1.0, 'Fare 항목 히스토그램')

# %%
# 3) Fare에서 이상치(상위 1%) 값의 개수를 계산하여 `q18_outlier_count` 변수에 저장 
top_1 = df['Fare'].quantile(.99)
cond = df['Fare'] >= top_1
q18_outlier_count = cond.sum()
print(f'이상치 개수 => {q18_outlier_count}개')
# Out:
# 이상치 개수 => 4개

# %%
# ======================================================================
# Q19. (실습 — 분포 시각화)  
# ======================================================================
# `titanic.csv` 데이터에서 다음을 수행하시오.

# 1) Age와 Fare 각각에 대해 히스토그램과 Boxplot을 그리시오.  
# 2) 두 변수의 분포 특징(대칭/비대칭, 이상치 존재 여부 등)을 아래 마크다운 셀에 간단히 서술하시오.

# %%
DATA_FILE = '../Exam/titanic.csv'
df = pd.read_csv(DATA_FILE)

# 1) Age와 Fare 각각에 대해 히스토그램과 Boxplot을 그리시오.
import matplotlib.pyplot as plt
import koreanize_matplotlib
# 히스토그램 그리기
plt.hist(df['Age'], bins=30)
plt.title('Age의 히스토그램')
plt.show()
plt.hist(df['Fare'], bins=30)
plt.title('Fare의 히스토그램')
plt.show()

# %%
# 1) Age와 Fare 각각에 대해 히스토그램과 Boxplot을 그리시오.
# Boxplot 그리기
plt.boxplot(df_age_filled['Age'])
plt.title('Age(결측치 처리)의 Boxplot')
plt.show()

plt.boxplot(df['Fare'])
plt.title('Fare의 Boxplot')
plt.show()

# %%
# ======================================================================
# [Q19 분포 해석] Age, Fare 분포 해석
# ======================================================================

# %% [markdown]
# #### 2) 두 변수의 분포 특징(대칭/비대칭, 이상치 존재 여부 등)을 아래 마크다운 셀에 간단히 서술하시오.
# 1. Age 변수
# - Age는 히스토그램이 중앙을 기준으로 완벽하진 않지만 어느정도 대칭을 보이고 있고,
# 박스플롯을 통해 양쪽으로 이상치가 존재한다는 것을 알 수 있다.
#
#
# 2. Fare 변수
# - Fare은 히스토그램이 왼쪽으로 치우친 비대칭 형태를 볼 수 있고,
# 박스플롯을 통해 오른쪽 꼬리에 이상치가 많이 존재한다는 것을 또 확인할 수 있다.

# %%
# ======================================================================
# Q20. (실습 — 관계)  
# ======================================================================
# `titanic.csv` 데이터에서 다음을 수행하시오.

# 1) Survived, Age, Fare, Pclass 사이의 상관계수 행렬 계산하고 `q20_corr` 변수에 저장  
# 2) `pandas.crosstab`을 사용하여 Sex와 Survived의 교차표를 만들고, `q20_crosstab` 변수에 저장  
# 3) 결과를 보고 Sex와 Survived 사이의 관계를 간단히 서술하시오.

# %%
DATA_FILE = '../Exam/titanic.csv'
df = pd.read_csv(DATA_FILE)

# 1) Survived, Age, Fare, Pclass 사이의 상관계수 행렬 계산하고 `q20_corr` 변수에 저장
df_new = df.iloc[:, [1,4,7,2]]
q20_corr = df_new.corr()
q20_corr
# Out:
#           Survived       Age      Fare    Pclass
# Survived  1.000000 -0.023837  0.060815 -0.117393
# Age      -0.023837  1.000000  0.375831 -0.412574
# Fare      0.060815  0.375831  1.000000 -0.896067
# Pclass   -0.117393 -0.412574 -0.896067  1.000000

# %%
# 2) `pandas.crosstab`을 사용하여 Sex와 Survived의 교차표를 만들고, `q20_crosstab` 변수에 저장 
q20_crosstab = pd.crosstab(df['Sex'], df['Survived'])
q20_crosstab
# Out:
# Survived    0   1
# Sex
# female     97  75
# male      178  50

# %%
# ======================================================================
# [Q20 해석] - Sex와 Survived 사이의 관계를 간단히 설명하세요.
# ======================================================================
df['Sex_encode'] = df['Sex'].astype('category').cat.codes
print(round(df['Sex_encode'].corr(df['Survived']),3))
print(round(df['Sex_encode'].corr(df['Survived'], method='spearman'),3))
print(round(df['Sex_encode'].corr(df['Survived'], method='kendall'),3))

'''
우선 크로스탭을 사용하여 교차표를 만들어본 결과에서는 타이타닉에서 죽은 사람의 성별은
여자보다 남자가 더 많고, 생존자는 여자가 더 많은 것을 볼 수 있다.
이를 통해 남자들이 많이 죽었고, 여자들은 약 반이 살았음을 알 수 있다.

Sex를 인코딩을 통해 값을 바꾸어 Survived와 직접 상관관계를 분석해본 결과,
약 -0.232의 상관계수를 보이는 것을 보아 음의 약한 상관관계를 보이는 것을 알 수 있었다.
'''
# Out:
# -0.232
# -0.232
# -0.232
# '\n우선 크로스탭을 사용하여 교차표를 만들어본 결과에서는 타이타닉에서 죽은 사람의 성별은\n여자보다 남자가 더 많고, 생존자는 여자가 더 많은 것을 볼 수 있다.\n이를 통해 남자들이 많이 죽었고, 여자들은 약 반이 살았음을 알 수 있다.\n\nSex를 인코딩을 통해 값을 바꾸어 Survived와 직접 상관관계를 분석해본 결과,\n약 -0.232의 상관계수를 보이는 것을 보아 음의 약한 상관관계를 보이는 것을 알 수 있었다.\n'
