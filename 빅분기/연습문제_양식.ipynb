# %% [markdown]
# ### [안내] FutureWarning은 미래 버전 예고라서, 코랩, 시험에서도 무시해도 됩니다.
# ~~~
# 코랩 흔히 발생하는 FutureWarning
# df['views'].fillna(min, inplace=True)  # 변경 전 (경고 발생, 무시해도 됨)
# df['views'] = df['views'].fillna(min)  # 변경 후 (권장 방식)
# ~~~

# %% [markdown]
# ### Section1.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data1.csv")

# Section 1. 필터링, 최소값, 중앙값

# 'f5' 컬럼이 0이 아닌 데이터(행)를 구하시오.
# 앞에서 구한 데이터에 ‘views’ 컬럼 결측치를 ‘views’ 컬럼의 최솟값으로 채워주세요.
# 그리고 ‘views’ 컬럼의 중앙값을 계산해 정수로 구하시오.

# %% [markdown]
# ### Section2.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data1.csv")

# Section 2. 카테고리, 인덱스, 문자열 슬라이싱

# 'subscribed' 컬럼에서 가장 빈도수가 많은 날짜를 구하시오.
# 앞에서 구한 날짜의 일(day) 값을 정수로 구하시오.

# %% [markdown]
# ### Section3.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data1.csv")

# Section 3. 파생변수, 정렬, 인덱싱

# 결측치가 있는 데이터(행)를 제거하시오.
# ‘views’ 컬럼을 ‘f1’ 컬럼으로 나눈 값을 새로운 컬럼으로 추가하시오.
# 새로운 컬럼 값 중 가장 큰 값을 가진 행의 age를 정수로 구하시오.

# %% [markdown]
# ### Section4.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data1.csv")

# Section 4. 값 변경, 정렬, 합계

# ‘views’ 컬럼의 결측 데이터를 0으로 대체하시오.
# ‘views’ 컬럼에서 상위 10번째 값을 구하시오.
# ‘views’ 컬럼에서 상위 10개의 값을 상위 10번째 값으로 대체하시오.
# ‘views’ 컬럼의 전체 합을 정수로 구하시오.

# %% [markdown]
# ### Section5.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data1.csv")

# Section 5. 문자열 슬라이싱, 파생변수, 평균값

# ‘f4’컬럼의 값 중에서 3번째와 4번째 문자가 ‘FJ’인 행(데이터)를 찾으시오.
# 찾은 데이터 중에서 ‘f2’ 컬럼의 평균값을 구하시오. (반올림 후 소수 둘째 자리까지 계산)

# %% [markdown]
# ### Section6.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data1.csv")

# Section 6. 필터링, 분산

# ‘f3’ 컬럼이 gold이면서 ‘f2’ 컬럼이 2인 데이터를 찾으시오.
# 찾은 데이터에서 ‘f1’ 컬럼의 분산을 구하시오. (반올림 후 소수 둘째 자리까지 계산)

# %% [markdown]
# ### Section7.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data1.csv")

# Section 7. 값 변경(연산), 필터링 절대값

# 모든 나이(age)에 1을 더하시오.
# 20대의 ‘views’ 평균과 30대의 ‘views’ 평균의 절댓값 차이를 구하시오. (반올림 후 소수 둘째 자리까지 계산)

# %% [markdown]
# ### Section8.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data1.csv")

# Section 8. 시계열 데이터, 필터링, 데이터 개수

# ‘subscribed’ 컬럼이 2024년 2월인 데이터를 찾으시오.
# 위에서 찾은 데이터 중 ‘f3’ 컬럼이 gold인 데이터의 개수를 구하시오.

# %% [markdown]
# ### Section9.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data1.csv")

# Section 9. 필터링, 카테고리, 최빈값

# ‘views’ 컬럼 값이 1000 이하인 데이터(결측치 제외)를 찾으시오.
# 앞에서 구한 데이터 중 ‘f4’ 컬럼의 최빈값을 구하시오.

# %% [markdown]
# ### Section10.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data1.csv")

# Section 10. 그룹핑, 최대값, 정렬

# 결측치가 있는 행을 삭제하시오.
# 결측치가 삭제된 데이터를 사용하여 지역별(city) 평균을 계산하시오.
# 앞에서 계산한 지역별 평균 데이터에서 'f2' 컬럼 값이 가장 큰 지역을 구하시오.

# %% [markdown]
# ### Section11.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data1.csv")

# Section 11. 슬라이싱, 사분위수, 결측치 제거

# 데이터에서 결측치가 있는 데이터(행)를 모두 제거하시오.
# 결측치가 제거된 데이터를 사용하여 앞에서부터 70% 데이터를 구하시오. (단, 데이터 70% 지점의 index가 소수점으로 계산될 경우 소수점 이하는 버림)
# 앞에서 구한 70% 데이터 중 ‘views’ 컬럼의 3사분위수에서 1사분위수를 뺀 값을 소수점 이하를 버리고 정수 부분만 구하시오.

# %% [markdown]
# ### Section12.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data1.csv")

# Section 12. 결측치 처리, 최빈값, 데이터 개수

# 결측치가 가장 많은 두 컬럼을 찾으시오.
# 첫 번째로 결측치가 많은 컬럼에서 결측치가 있는 데이터(행)를 삭제하시오.
# 두 번째로 결측치가 많은 컬럼의 결측값을 그 컬럼의 최빈값으로 대체하시오.
# ‘f3’ 컬럼의 ‘gold’ 값을 가진 데이터의 수를 정수형으로 구하시오.

# %% [markdown]
# ### Section13.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data1.csv")

# Section 13. 결측 데이터 찾기, 필터링, 평균값

# ‘f1’ 컬럼에 결측치가 있는 데이터만 선택하시오.
# 선택된 데이터에서 ‘age’ 컬럼의 평균값을 구하시오. (반올림 후 소수 첫째 자리까지 계산)

# %% [markdown]
# ### Section14.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data1.csv")

# Section 14. 중복데이터 제거, 값 변경, 데이터 개수

# 중복 데이터를 제거하시오. (단, 중복이 발생한 경우 뒤에 나온 행을 제거한다.)
# ‘f3’ 컬럼의 결측치는 0, 'silver'는 1, 'gold'는 2, 'vip'는 3으로 변환하시오.
# 변환된 ‘f3’ 컬럼의 총합을 정수형으로 구하시오.

# %% [markdown]
# ### Section15.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data1.csv")

# Section 15. 컬럼 삭제, 행 단위 합계, 필터링

# 주어진 데이터에서 문자 자료형 컬럼을 삭제하시오.
# 숫자 자료형 컬럼의 결측치를 0으로 대체하시오.
# 각 행의 합이 3000보다 큰 값의 개수를 정수로 구하시오. (각 행의 합: ‘age’ + ‘f1’ + ‘f2’ + ‘f5’ + ‘views’)

# %% [markdown]
# ### Section16.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data1.csv")

# Section 16. 이상치, IQR

# 'views' 컬럼의 1사분위수, 3사분위수 그리고 IQR을 계산하시오.
# 이상치 조건에 맞는 데이터를 찾으시오. (이상치는 1사분위수 – (IQR * 1.5)보다 작은 값과 3사분위수 + (IQR * 1.5)보다 큰 값)

# %% [markdown]
# ### Section17.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data1.csv")

# Section 17. 이상치, 소수점 있는 데이터 찾기, 표준편차

# ‘views’ 컬럼의 표준편차를 구하시오.
# ‘age’ 컬럼의 이상치(소수점 나이, 음수 나이, 0살)를 제거하고, ‘views’ 컬럼의 표준편차를 구하시오.
# 이상치 제거 전후의 ‘views’ 컬럼의 표준편차를 더하여, 반올림 후 소수 둘째 자리까지 구하시오.

# %% [markdown]
# ### Section18.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data2.csv", index_col="year")

# Section 18. 데이터(행) 기준 평균값, 인덱싱

# index '2001' 데이터(행)에서 평균보다 큰 값의 개수를 구하시오.
# index '2003' 데이터(행)에서 평균보다 작은 값의 개수를 구하시오.
# 두 개수를 더하시오.

# %% [markdown]
# ### Section19.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data1.csv")

# Section 19. 결측치(뒤에 값으로 대체), 그룹합

# 결측치를 바로 뒤에 있는 값으로 대체하시오. (바로 뒤의 값도 결측치일 경우, 뒤에 있는 데이터 중 가장 가까운 값으로 대체)
# 'city'와 'f2' 컬럼을 기준으로 그룹합을 계산하시오.
# 'views' 값이 세 번째로 큰 city 이름을 구하시오.

# %% [markdown]
# ### Section20.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/type1_data1.csv")

# Section 20. 시계열 데이터, 월별 집계, 인덱스

# 연도 구분 없이 월별로 숫자형 컬럼의 합을 구하시오.
# 합계 중 'views'가 가장 작은 값을 가진 월을 정수로 구하시오.

# %% [markdown]
# ### Section21.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/delivery_time.csv")

# Section 21. 시간 간의 차이 계산(분), 필터링

# 예상 도착 시간보다 늦게 도착한 건수를 구하시오.
# 이 중 거리가 7km 이상인 데이터의 수를 정수로 구하시오.

# %% [markdown]
# ### Section22.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/delivery_time.csv")

# Section 22. 시간 간의 차이 계산(분), 그룹핑

# 주문 시간과 실제 도착 시간의 차이를 분 단위로 계산하시오.
# 앱 종류별로 평균 도착 시간(분)을 계산하시오.
# 평균적으로 가장 빠른 앱 종류를 찾고, 해당 앱의 평균 도착 시간을 분으로 반올림하여 정수로 구하시오.

# %% [markdown]
# ### Section23.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/delivery_time.csv")

# Section 23. 시간 간의 차이 계산(분), 비율

# 각 결제 종류별로 실제 도착 시간이 예상 도착 시간보다 늦은 주문의 비율을 계산하시오.
# 비율 중 가장 큰 값을 반올림하여 소수 둘째 자리까지 구하시오.

# %% [markdown]
# ### Section24.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/delivery_time.csv")

# Section 24. 그룹핑, 값 찾기, 필터링

# 사용자별 주문 거리의 합계가 50km 이상인 사람들의 결제 방식을 구하시오.
# 이 결제 방식 중 가장 빈도가 높은 수를 구하시오.

# %% [markdown]
# ### Section25.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/delivery_time.csv")

# Section 25. 시간 간의 차이 계산(일)

# 각 사용자별로 첫 주문과 마지막 주문 사이의 시간 간격을 일 단위로 계산하시오.
# 한 번만 주문했거나, 같은 날 주문이 이루어진 사용자(시간 간격이 0일인 사용자)는 제외하고, 나머지 사용자들의 평균 시간 간격(일 단위)을 계산하시오.
# 평균 시간 간격보다 긴 시간 간격을 가진 사용자의 수를 정수로 구하시오.

# %% [markdown]
# ### Section26.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/delivery_time.csv")

# Section 26. 날짜와 시간정보 변환, 비율

# 주문이 가장 많이 발생한 연-월을 찾으시오.
# 해당 연-월에 '배고팡' 앱을 통한 주문 중 '앱결제'로 결제된 주문의 비율을 계산하시오. (반올림 후 소수 둘째 자리까지 계산)

# %% [markdown]
# ### Section27.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/delivery_time.csv")

# Section 27. 시간 범위, 속도(km/h)

# 점심시간(10시부터 13시 전까지)에 주문된 배달 데이터를 찾으시오.
# 점심시간 주문 건 중 과속(평균 속도가 50km/h 이상)하는 주문 수를 정수로 구하시오.
# 배달시간 = 실제도착시간 - 주문시간
# 속도(km/h) = 거리(km) / 시간(h)

# %% [markdown]
# ### Section28.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/delivery_time.csv")

# Section 28. 날짜와 시간, 문자열

# 연도와 월을 기준으로 주문 수를 집계하시오.
# 가장 많은 주문이 있었던 연도와 월을 예시와 같은 형식으로 숫자로만 구하시오. (예: 2024년 2월인 경우 ‘202402’, 2024년 10월인 경우 ‘202410’)

# %% [markdown]
# ### Section29.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/delivery_time.csv")

# Section 29. 함수, 월별 집계

# 배달료 계산 기준표에 따라 각 주문에 대한 배달료를 계산하시오.
# 월별로 배달료의 총합을 집계하시오.
# 배달료가 가장 많이 발생한 월을 찾고, 그 월의 총 배달료를 정수로 구하시오.
# [배달료 기준표]
# - 5km 미만: 2000원
# - 5km 이상 ~ 10km 미만: 4000원
# - 10km 이상 ~ 15km 미만: 6000원
# - 15km 이상 ~ 20km 미만: 8000원

# %% [markdown]
# ### Section30.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/delivery_time.csv")

# Section 30. 주말, 평일 구분

# 주말 주문 건수와 평일 주문 건수를 구하시오.
# 주말 주문 건수와 평일 주문 건수의 차이를 절댓값으로 구하여 정수형으로 구하시오.

# %% [markdown]
# ### Section31.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/delivery_time.csv")

# Section 31. 문자열, 형 변환

# 'user' 컬럼에서 user뒤에 있는 숫자 값만 추출하시오.
# 추출된 숫자 값을 모두 합한 값을 정수로 구하시오.

# %% [markdown]
# ### Section32.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/school_data.csv")

# Section 32. 합계(열 방향), 상위 값 선택

# 수학, 영어, 국어 점수의 합을 구하시오.
# 합이 가장 큰 상위 10명을 찾으시오.
# 찾은 10명의 수학 평균 점수를 구하시오. (반올림 후 정수 출력)

# %% [markdown]
# ### Section33.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/school_data.csv")

# Section 33. 데이터프레임 재구조화

# 과목에 상관없이 점수가 가장 작은 점수 25개를 찾으시오.
# 찾은 점수 25개의 합을 정수로 구하시오.

# %% [markdown]
# ### Section34.

# %%
import pandas as pd
# school_data
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/school_data.csv")

# school_data_science
df_science = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/school_data_science.csv")

# Section 34. 데이터 합치기 (concat)

# school_data.csv와 school_data_science.csv의 학생 순서는 동일하다.
# 학생별로 수학, 영어, 국어, 과학 점수의 평균을 구하시오.
# 평균 점수가 60점 이상인 인원 수를 계산하시오.

# %% [markdown]
# ### Section35.

# %%
import pandas as pd
# school_data
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/school_data.csv")

# school_data_social
df_social = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p1/school_data_social.csv")

# Section 35. 데이터 합치기 (merge)

# school_data.csv와 school_data_social.csv 파일을 '이름'을 기준으로 합치시오.
# 영어교사가 장선생이면서 사회교사가 오선생인 학생들을 필터링하시오.
# 필터링된 학생들의 수학 점수를 모두 더한 후 정수로 구하시오.

# %% [markdown]
# ### Section36.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert_v2/refs/heads/main/part1/ch3/sales.csv")

# Section 36 조건별 변환 (transform)

# 결측된 판매금액은 해당 지역의 평균 판매금액으로 결측값을 대체하시오.
# 각 거래마다 “판매금액”과 해당 지역의 평균 판매금액의 "차이"를 절대값으로 구하시오.
# 각 지역에서 차이값의 평균을 구한 후, 이 값이 가장 큰 지역의 지역코드를 구하시오.

# %% [markdown]
# ### Section37.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert_v2/refs/heads/main/part1/ch3/store_sales.csv")

# Section 37. 재구조화 (unstack), 맵핑

# 각 행에서 판매수량과 단가를 이용하여 매출액을 계산하세요.
# 요일을 평일과 주말로 구분하고, 매장별 평일과 주말 매출액 합계를 구하시오.
# 매장별 평일과 주말 매출액 차이를 절대값으로 구하세요. 이후, 모든 매장 중 가장 큰 절대값 차이를 찾으시오.

# %% [markdown]
# ### Section38.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert_v2/refs/heads/main/part1/ch3/region_sales.csv")

# Section 38. 피벗테이블

# 각 Region과 Channel 조합별로 제품(Product) A, B의 총 판매액을 계산하시오.
# 제품 A의 매출 비율(A비율)을 구하세요. A비율 = (제품 A 판매액) ÷ (제품 A 판매액 + 제품 B 판매액)
# A비율 중 최댓값을 찾아 반올림하여 소수 둘째 자리까지 구하시오.

# %% [markdown]
# ### Section39.

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert_v2/refs/heads/main/part1/ch3/monthly_sales.csv')

# Section 39. 재구조화(melt), 그룹핑

# 지역(Region)과 월(Jan, Feb, Mar)별 매출(Sales) 합계를 구하시오.
# 위에서 구한 결과 중, 매출 합계(Sales)가 1400을 초과하는 경우가 몇 건인지 구하시오.
