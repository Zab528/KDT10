# %% [markdown]
# #### 【 자연어 처리용 형태소분석 - NLTK 】
# - 단어/어휘사전 추출
#     * 정제
#     * 토큰화
#     * 불용어/구두점
#     * 어근추출 => 표제어/어간추출

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비<hr>

# %%
## [1-1] 모듈 로딩
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords 
from string import punctuation
from nltk.tag import pos_tag 
from nltk.stem import WordNetLemmatizer, PorterStemmer 

from collections import Counter

# %%
## [1-2] 데이터 준비
DATA_FILE = '../Data/Louis_Jean_Joseph.txt'

# %%
## [1-3] 데이터 로딩
with open(DATA_FILE, mode='r') as f:
    allData = f.read()

print(f'allData => {len(allData)}개')
print(f'allData => {allData[:100]}')
# Out:
# allData => 11101개
# allData => Louis Jean Joseph Leblanc (born January 26, 1991) is a Canadian former professional ice hockey playe

# %% [markdown]
# [2] 텍스트 데이터 전처리<hr>
# - 기본 정제 :  구두점, 언어별 불용어
# - 토큰화 진행 => 토큰 기반 정제 필요할 수 있음!
# - 어근/원형 변환 => 어간추출/표제어추출
# - 영어 경우 대소문자 일치

# %%
## ====================================================================
## 품사태깅작업 : 정확하게 형태소 분리 위해서 진행 => 토큰 단위로 진행
## ====================================================================
text = allData[:100]

tk_pos = pos_tag( word_tokenize(text) , tagset='universal' )
tkList = []
for tk, pos in tk_pos:
    if pos in ['NOUN', 'VERB']:
        tkList.append(tk)

print("선택된 태그 : ", tkList)
# Out:
# 선택된 태그 :  ['Louis', 'Jean', 'Joseph', 'Leblanc', 'born', 'January', 'is', 'professional', 'ice', 'hockey', 'playe']

# %%
## ====================================================================
## [2-1] 전처리 준비
## ====================================================================
## - 노이즈 데이터 필터링 준비
puncList = list(punctuation)
swList   = stopwords.words("english")

## - 영문 대소문자 일치
allData = allData.lower()

# %%
## ====================================================================
## [2-2] 토큰화 진행 
## -> 문장 단위 인코딩을 위한 문장 단위 토큰 저장
## -> 어휘사전용 토큰 저장 
## ====================================================================
allTKList, sentTKList = [], []

sentList = sent_tokenize(allData)
print(f'sentList: {len(sentList)}개')

wnLem = WordNetLemmatizer()

for sent in sentList:
    wTK = word_tokenize(sent)

    sentTK = []
    tk_pos = pos_tag( wTK , tagset='universal' )
    for tk, pos in tk_pos:
        if (pos in ['NOUN', 'VERB']) and (tk not in swList+puncList):
            if pos == 'VERB': tk=wnLem.lemmatize(tk, pos='v')
            allTKList.append(tk)
            sentTK.append(tk)
    if sentTK: sentTKList.append(sentTK)

print(f'allTKList => {len(allTKList)}개\n{allTKList}')
print(f'sentTKList  => {len(sentTKList)}개')
print(sentTKList[-1])
# Out:
# sentList: 70개
# allTKList => 794개
# ['jean', 'joseph', 'leblanc', 'january', 'professional', 'ice', 'hockey', 'player', 'centre', 'leblanc', 'play', 'hockey', 'region', 'move', 'states', 'play', 'season', 'lancers', 'states', 'hockey', 'league', 'become', 'rookie', 'year', 'entry', 'draft', 'select', 'montreal', 'canadiens', 'enrol', 'harvard', 'university', 'spend', 'season', 'crimson', 'name', 'ivy', 'league', 'rookie', 'year', 'sign', 'contract', 'canadiens', 'year', 'leblanc', 'join', 'montreal', 'juniors', 'acquire', 'quebec', 'junior', 'hockey', 'league', 'qmjhl', 'playing', 'rights', 'leblanc', 'spend', 'seasons', 'canadiens', 'organization', 'play', 'hockey', 'league', 'ahl', 'affiliate', 'appear', 'hockey', 'league', 'games', 'seasons', 'trade', 'anaheim', 'ducks', 'keep', 'ahl', 'leblanc', 'move', 'europe', 'join', 'hc', 'slovan', 'bratislava', 'hockey', 'league', 'khl', 'play', 'games', 'release', 'appear', 'games', 'hc', 'league', 'retire', 'hockey', 'play', 'ivan', 'hlinka', 'tournament', 'canada', 'gold', 'medal', 'world', 'junior', 'ice', 'hockey', 'championships', 'help', 'canada', 'win', 'silver', 'medal', 'leblanc', 'consider', 'draft', 'bust', 'fail', 'reach', 'retire', 'hockey', 'age', 'life', 'leblanc', 'bear', 'yves', 'marie', 'leblanc', 'pointe-claire', 'suburb', 'montreal', 'yves', 'leblanc', 'employ', 'chemist', 'merck', 'frosst', 'world', 'companies', 'montreal', 'transfer', 'facility', 'cambridge', 'massachusetts', 'work', 'weeks', 'return', 'montreal', 'weekends', 'marie', 'piano', 'teacher', 'louis', 'brother', 'jean', 'play', 'hockey', 'grow', 'west', 'island', 'town', 'kirkland', 'quebec', 'leblanc', 'skate', 'age', 'enter', 'organize', 'years', 'youth', 'play', 'pee-wee', 'hockey', 'tournament', 'lakeshore', 'hockey', 'association', 'play', 'lakeshore', 'become', 'could', 'pursue', 'sport', 'level', 'age', 'join', 'st.', 'louis', 'lions', 'midget', 'team', 'base', 'montreal', 'play', 'seasons', 'lions', 'lead', 'league', 'score', 'times', 'leblanc', 'select', 'foreurs', 'quebec', 'junior', 'hockey', 'league', 'qmjhl', 'draft', 'wish', 'attend', 'university', 'go', 'lancers', 'states', 'hockey', 'league', 'ushl', 'spend', 'season', 'play', 'games', 'finish', 'goals', 'assists', 'points', 'lead', 'team', 'points', 'score', 'tie', 'tenth', 'ushl', 'goal', 'total', 'tie', 'goals', 'leblanc', 'score', 'tie', 'recognition', 'performance', 'season', 'ushl', 'name', 'league', 'rookie', 'year', 'end', 'season', 'leblanc', 'rank', 'scout', 'bureau', 'prospect', 'entry', 'draft', 'list', 'skaters', 'select', 'montreal', 'canadiens', 'host', 'draft', 'francophone', 'select', 'round', 'entry', 'draft', 'canadiens', 'chouinard', 'coaches', 'scouts', 'canadiens', 'praise', 'leblanc', 'speed', 'determination', 'ability', 'willingness', 'go', 'corners', 'puck', 'canadiens', 'manager', 'bob', 'gainey', 'felt', 'leblanc', 'decision', 'move', 'states', 'play', 'ushl—rather', 'stay', 'quebec', 'qmjhl', 'would', 'choice—would', 'help', 'development', 'player', 'display', 'type', 'character', 'team', 'seek', 'leblanc', 'enrol', 'harvard', 'university', 'september', 'begin', 'play', 'university', 'hockey', 'team', 'crimson', 'year', 'harvard', 'lead', 'team', 'goals', 'assists', 'points', 'name', 'ivy', 'league', 'rookie', 'year', 'finalist', 'rookie', 'year', 'mid-2010', 'leblanc', 'qmjhl', 'rights', 'own', 'montreal', 'hockey', 'club', 'juniors', '—his', 'rights', 'trade', "val-d'or", 'chicoutimi', 'saguenéens', 'juniors', 'june', 'july', 'leblanc', 'sign', 'contract', 'canadiens', 'attend', 'training', 'camp', 'team', 'september', 'sign', 'contract', 'forfeit', 'collegiate', 'association', 'eligibility', 'leave', 'harvard', 'consider', 'accord', 'standards', 'follow', 'camp', 'canadiens', 'announce', 'september', 'return', 'juniors', 'season', 'finish', 'points', 'games', 'juniors', 'off-season', 'team', 'relocate', 'boisbriand', 'suburb', 'montreal', 'rename', 'blainville-boisbriand', 'armada', 'team', 'trade', 'leblanc', 'junior', 'rights', 'catarac ...
# sentTKList  => 69개
# ['announce', 'retirement', 'report', 'plan', 'return', 'harvard', 'year']

# %% [markdown]
# [3] 단어/어휘 사전 생성<hr>

# %%
## [3-1] 토큰의 빈도수 체크 및 내림차순 정렬 
allTKDict  = dict(Counter(allTKList))
rAllTKList = sorted(allTKDict.items(), key=lambda k: k[1], reverse=True)
rAllTKList
# Out:
# [('leblanc', 42),
#  ('hockey', 21),
#  ('play', 21),
#  ('team', 19),
#  ('canadiens', 18),
#  ('league', 17),
#  ('games', 16),
#  ('season', 13),
#  ('montreal', 11),
#  ('points', 11),
#  ('year', 10),
#  ('score', 10),
#  ('draft', 8),
#  ('ahl', 8),
#  ('goals', 8),
#  ('sign', 7),
#  ('contract', 7),
#  ('junior', 7),
#  ('assists', 7),
#  ('harvard', 6),
#  ('university', 6),
#  ('juniors', 6),
#  ('tournament', 6),
#  ('canada', 6),
#  ('goal', 6),
#  ('camp', 6),
#  ('move', 5),
#  ('rookie', 5),
#  ('join', 5),
#  ('rights', 5),
#  ('fail', 5),
#  ('hamilton', 5),
#  ('record', 5),
#  ('players', 5),
#  ('states', 4),
#  ('entry', 4),
#  ('select', 4),
#  ('spend', 4),
#  ('name', 4),
#  ('quebec', 4),
#  ('qmjhl', 4),
#  ('affiliate', 4),
#  ('trade', 4),
#  ('ducks', 4),
#  ('hc', 4),
#  ('medal', 4),
#  ('world', 4),
#  ('lead', 4),
#  ('finish', 4),
#  ('bulldogs', 4),
#  ('assist', 4),
#  ('ice', 3),
#  ('player', 3),
#  ('seasons', 3),
#  ('anaheim', 3),
#  ('slovan', 3),
#  ('khl', 3),
#  ('release', 3),
#  ('retire', 3),
#  ('gold', 3),
#  ('consider', 3),
#  ('age', 3),
#  ('return', 3),
#  ('go', 3),
#  ('ushl', 3),
#  ('tie', 3),
#  ('september', 3),
#  ('june', 3),
#  ('make', 3),
#  ('point', 3),
#  ('december', 3),
#  ('nhl', 3),
#  ('time', 3),
#  ('assign', 3),
#  ('roster', 3),
#  ('game', 3),
#  ('jean', 2),
#  ('region', 2),
#  ('lancers', 2),
#  ('become', 2),
#  ('enrol', 2),
#  ('crimson', 2),
#  ('ivy', 2),
#  ('playing', 2),
#  ('appear', 2),
#  ('bratislava', 2),
#  ('ivan', 2),
#  ('hlinka', 2),
#  ('championships', 2),
#  ('help', 2),
#  ('reach', 2),
#  ('life', 2),
#  ('yves', 2),
#  ('marie', 2),
#  ('suburb', 2),
#  ('louis', 2),
#  ('lakeshore', 2),
#  ('association', 2),
#  ('st.', 2),
#  ('lions', 2),
#  ('attend', 2),
#  ('stay', 2),
#  ('july', 2),
#  ('follow', 2),
#  ('announce', 2),
#  ('cataractes', 2),
#  ('debut', 2),
#  ('give', 2),
#  ('recall', 2),
#  ('restrict', 2),
#  ('limit', 2),
#  ('cut', 2),
#  ('agent', 2),
#  ('york', 2),
#  ('coach', 2),
#  ('republic', 2),
#  ('add', 2),
#  ('invite', 2),
#  ('ncaa', 2),
#  ('chl', 2),
#  ('russia', 2),
#  ('joseph', 1),
#  ('january', 1),
#  ('professional', 1),
#  ('centre', 1),
#  ('acquire', 1),
#  ('organization', 1),
#  ('keep', 1),
#  ('europe', 1),
#  ('win', 1),
#  ('silver', 1),
#  ('bust', 1),
#  ('bear', 1),
#  ('pointe-claire', 1),
#  ('employ', 1),
#  ('chemist', 1),
#  ('merck', 1),
#  ('frosst', 1),
#  ('companies', 1),
#  ('transfer', 1),
#  ('facility', 1),
#  ('cambridge', 1),
#  ('massachusetts', 1),
#  ('work', 1),
#  ('weeks', 1),
#  ('weekends', 1),
#  ('piano', 1),
#  ('teacher', 1),
#  ('brother', 1),
#  ('grow', 1),
#  ('west', 1),
#  ('island', 1),
#  ('town', 1),
#  ('kirkland', 1),
#  ('skate', 1),
#  ('enter', 1),
#  ('organize', 1),
#  ('years', 1),
#  ('youth', 1),
#  ('pee-wee', 1),
#  ('could', 1),
#  ('pursue', 1),
#  ('sport', 1),
#  ('level', 1),
#  ('midget', 1),
#  ('base', 1),
#  ('times', 1),
#  ('foreurs', 1),
#  ('wish', 1),
#  ('tenth', 1),
#  ('total', 1),
#  ('recognition', 1),
#  ('performance', 1),
#  ('end', 1),
#  ('rank', 1),
#  ('scout', 1),
#  ('bureau', 1),
#  ('prospect', 1),
#  ('list', 1),
#  ('skaters', 1),
#  ('host', 1),
#  ('francophone', 1),
#  ('round', 1),
#  ('chouinard', 1),
#  ('coaches', 1),
#  ('scouts', 1),
#  ('praise', 1),
#  ('speed', 1),
#  ('determination', 1),
#  ('ability', 1),
#  ('willingness', 1),
#  ('corners', 1),
#  ('puck', 1),
#  ('manager', 1),
#  ('bob', 1),
#  ('gainey', 1),
#  ('felt', 1),
#  ('decision', 1),
#  ('ushl—rather', 1),
#  ('would', 1),
#  ('choice—would', 1),
#  ('development', 1),
#  ('display', 1),
#  ('type', 1),
#  ('character', 1),
#  ('seek', 1),
#  ('begin', 1),
#  ('finalist', 1),
#  ('mid-2010', 1),
#  ('own', 1),
#  ('club', 1),
#  ('—his', 1),
#  ("val-d'or", 1),
#  ('chicoutimi', 1),
#  ('saguenéens', 1),
#  ('training', 1),
#  ('forfeit', 1),
#  ('collegiate', 1),
#  ('eligibility', 1),
#  ('leave', 1),
#  ('accord', 1),
#  ('standards', 1),
#  ('off-season', 1),
#  ('relocate', 1),
#  ('boisbriand', 1),
#  ('rename', 1),
#  ('blainville-boisbriand', 1),
#  ('armada', 1),
#  ('chance', 1),
#  ('exercise', 1),
#  ('put', 1),
#  ('include', 1),
#  ('overtime', 1),
#  ('victory', 1),
#  ('rochester', 1),
#  ('americans', 1),
#  ('kostitsyn', 1),
#  ('come', 1),
#  ('los', 1),
#  ('angeles', 1),
#  ('kings', 1),
#  ('bobrovsky', 1),
#  ('loss', 1),
#  ('philadelphia', 1),
#  ('flyers', 1),
#  ('split', 1),
#  ('remainder', 1),
#  ('goal-scorer', 1),
#  ('rookies', 1),
#  ('second', 1),
#  ('delay', 1),
#  ('lockout', 1),
#  ('resume', 1),
#  ('injuries', 1),
#  ('production', 1),
#  ('demotion', 1),
#  ('speculate', 1),
#  ('media', 1),
#  ('remain', 1),
#  ('future', 1),
#  ('pointless', 1),
#  ('send', 1),
#  ('career', 1),
#  ('question', 1),
#  ('establish', 1),
#  ('exchange', 1),
#  ('fifth-round', 1),
#  ('pick', 1),
#  ('extension', 1),
#  ('norfolk', 1),
#  ('admirals', 1),
#  ('islanders', 1),
#  ('secure', 1),
#  ('spot', 1),
#  ('lineup', 1),
#  ('bridgeport', 1),
#  ('sound', 1),
#  ('tigers', 1),
#  ('agree', 1),
#  ('visa', 1),
#  ('issues', 1),
#  ('prevent', 1),
#  ('loan', 1),
#  ('mshk', 1),
#  ('žilina', 1),
#  ('slovak', 1),
#  ('extraliga', 1),
#  ('clear', 1),
#  ('criticize', 1),
#  ('miloš', 1),
#  ('říha', 1),
#  ('need', 1),
#  ('retain', 1),
#  ('place', 1),
#  ('judge', 1),
#  ('meet', 1),
#  ('standard', 1),
#  ('nla', 1),
#  ('decide', 1),
#  ('busts', 1),
#  ('period', 1),
#  ('expect', 1),
#  ('selection', 1),
#  ('participate', 1),
#  ('czech', 1),
#  ('slovakia', 1),
#  ('try', 1),
#  ('speculation', 1),
#  ('participation', 1),
#  ('hinder', 1),
#  ('chances', 1),
#  ('exams', 1),
#  ('schedule', 1),
#  ('summer', 1),
#  ('john', 1),
#  ('newfoundland', 1),
#  ('labrador', 1),
#  ('scorers', 1),
#  ('earn', 1),
#  ('lose', 1),
#  ('relationship', 1),
#  ('tennis', 1),
#  ('aleksandra', 1),
#  ('wozniak', 1),
#  ('critique', 1),
#  ('twitter', 1),
#  ('say', 1),
#  ('shot', 1),
#  ('major', 1),
#  ('economics', 1),
#  ('turn', 1),
#  ('take', 1),
#  ('business', 1),
#  ('class', 1),
#  ('mcgill', 1),
#  ('city', 1),
#  ('retirement', 1),
#  ('report', 1),
#  ('plan', 1)]

# %%
## [3-2] 단어/어휘 사전 생성
vocab = {'oov': 0}
for tk, _ in rAllTKList:
    vocab[tk]=len(vocab)
vocab
# Out:
# {'oov': 0,
#  'leblanc': 1,
#  'hockey': 2,
#  'play': 3,
#  'team': 4,
#  'canadiens': 5,
#  'league': 6,
#  'games': 7,
#  'season': 8,
#  'montreal': 9,
#  'points': 10,
#  'year': 11,
#  'score': 12,
#  'draft': 13,
#  'ahl': 14,
#  'goals': 15,
#  'sign': 16,
#  'contract': 17,
#  'junior': 18,
#  'assists': 19,
#  'harvard': 20,
#  'university': 21,
#  'juniors': 22,
#  'tournament': 23,
#  'canada': 24,
#  'goal': 25,
#  'camp': 26,
#  'move': 27,
#  'rookie': 28,
#  'join': 29,
#  'rights': 30,
#  'fail': 31,
#  'hamilton': 32,
#  'record': 33,
#  'players': 34,
#  'states': 35,
#  'entry': 36,
#  'select': 37,
#  'spend': 38,
#  'name': 39,
#  'quebec': 40,
#  'qmjhl': 41,
#  'affiliate': 42,
#  'trade': 43,
#  'ducks': 44,
#  'hc': 45,
#  'medal': 46,
#  'world': 47,
#  'lead': 48,
#  'finish': 49,
#  'bulldogs': 50,
#  'assist': 51,
#  'ice': 52,
#  'player': 53,
#  'seasons': 54,
#  'anaheim': 55,
#  'slovan': 56,
#  'khl': 57,
#  'release': 58,
#  'retire': 59,
#  'gold': 60,
#  'consider': 61,
#  'age': 62,
#  'return': 63,
#  'go': 64,
#  'ushl': 65,
#  'tie': 66,
#  'september': 67,
#  'june': 68,
#  'make': 69,
#  'point': 70,
#  'december': 71,
#  'nhl': 72,
#  'time': 73,
#  'assign': 74,
#  'roster': 75,
#  'game': 76,
#  'jean': 77,
#  'region': 78,
#  'lancers': 79,
#  'become': 80,
#  'enrol': 81,
#  'crimson': 82,
#  'ivy': 83,
#  'playing': 84,
#  'appear': 85,
#  'bratislava': 86,
#  'ivan': 87,
#  'hlinka': 88,
#  'championships': 89,
#  'help': 90,
#  'reach': 91,
#  'life': 92,
#  'yves': 93,
#  'marie': 94,
#  'suburb': 95,
#  'louis': 96,
#  'lakeshore': 97,
#  'association': 98,
#  'st.': 99,
#  'lions': 100,
#  'attend': 101,
#  'stay': 102,
#  'july': 103,
#  'follow': 104,
#  'announce': 105,
#  'cataractes': 106,
#  'debut': 107,
#  'give': 108,
#  'recall': 109,
#  'restrict': 110,
#  'limit': 111,
#  'cut': 112,
#  'agent': 113,
#  'york': 114,
#  'coach': 115,
#  'republic': 116,
#  'add': 117,
#  'invite': 118,
#  'ncaa': 119,
#  'chl': 120,
#  'russia': 121,
#  'joseph': 122,
#  'january': 123,
#  'professional': 124,
#  'centre': 125,
#  'acquire': 126,
#  'organization': 127,
#  'keep': 128,
#  'europe': 129,
#  'win': 130,
#  'silver': 131,
#  'bust': 132,
#  'bear': 133,
#  'pointe-claire': 134,
#  'employ': 135,
#  'chemist': 136,
#  'merck': 137,
#  'frosst': 138,
#  'companies': 139,
#  'transfer': 140,
#  'facility': 141,
#  'cambridge': 142,
#  'massachusetts': 143,
#  'work': 144,
#  'weeks': 145,
#  'weekends': 146,
#  'piano': 147,
#  'teacher': 148,
#  'brother': 149,
#  'grow': 150,
#  'west': 151,
#  'island': 152,
#  'town': 153,
#  'kirkland': 154,
#  'skate': 155,
#  'enter': 156,
#  'organize': 157,
#  'years': 158,
#  'youth': 159,
#  'pee-wee': 160,
#  'could': 161,
#  'pursue': 162,
#  'sport': 163,
#  'level': 164,
#  'midget': 165,
#  'base': 166,
#  'times': 167,
#  'foreurs': 168,
#  'wish': 169,
#  'tenth': 170,
#  'total': 171,
#  'recognition': 172,
#  'performance': 173,
#  'end': 174,
#  'rank': 175,
#  'scout': 176,
#  'bureau': 177,
#  'prospect': 178,
#  'list': 179,
#  'skaters': 180,
#  'host': 181,
#  'francophone': 182,
#  'round': 183,
#  'chouinard': 184,
#  'coaches': 185,
#  'scouts': 186,
#  'praise': 187,
#  'speed': 188,
#  'determination': 189,
#  'ability': 190,
#  'willingness': 191,
#  'corners': 192,
#  'puck': 193,
#  'manager': 194,
#  'bob': 195,
#  'gainey': 196,
#  'felt': 197,
#  'decision': 198,
#  'ushl—rather': 199,
#  'would': 200,
#  'choice—would': 201,
#  'development': 202,
#  'display': 203,
#  'type': 204,
#  'character': 205,
#  'seek': 206,
#  'begin': 207,
#  'finalist': 208,
#  'mid-2010': 209,
#  'own': 210,
#  'club': 211,
#  '—his': 212,
#  "val-d'or": 213,
#  'chicoutimi': 214,
#  'saguenéens': 215,
#  'training': 216,
#  'forfeit': 217,
#  'collegiate': 218,
#  'eligibility': 219,
#  'leave': 220,
#  'accord': 221,
#  'standards': 222,
#  'off-season': 223,
#  'relocate': 224,
#  'boisbriand': 225,
#  'rename': 226,
#  'blainville-boisbriand': 227,
#  'armada': 228,
#  'chance': 229,
#  'exercise': 230,
#  'put': 231,
#  'include': 232,
#  'overtime': 233,
#  'victory': 234,
#  'rochester': 235,
#  'americans': 236,
#  'kostitsyn': 237,
#  'come': 238,
#  'los': 239,
#  'angeles': 240,
#  'kings': 241,
#  'bobrovsky': 242,
#  'loss': 243,
#  'philadelphia': 244,
#  'flyers': 245,
#  'split': 246,
#  'remainder': 247,
#  'goal-scorer': 248,
#  'rookies': 249,
#  'second': 250,
#  'delay': 251,
#  'lockout': 252,
#  'resume': 253,
#  'injuries': 254,
#  'production': 255,
#  'demotion': 256,
#  'speculate': 257,
#  'media': 258,
#  'remain': 259,
#  'future': 260,
#  'pointless': 261,
#  'send': 262,
#  'career': 263,
#  'question': 264,
#  'establish': 265,
#  'exchange': 266,
#  'fifth-round': 267,
#  'pick': 268,
#  'extension': 269,
#  'norfolk': 270,
#  'admirals': 271,
#  'islanders': 272,
#  'secure': 273,
#  'spot': 274,
#  'lineup': 275,
#  'bridgeport': 276,
#  'sound': 277,
#  'tigers': 278,
#  'agree': 279,
#  'visa': 280,
#  'issues': 281,
#  'prevent': 282,
#  'loan': 283,
#  'mshk': 284,
#  'žilina': 285,
#  'slovak': 286,
#  'extraliga': 287,
#  'clear': 288,
#  'criticize': 289,
#  'miloš': 290,
#  'říha': 291,
#  'need': 292,
#  'retain': 293,
#  'place': 294,
#  'judge': 295,
#  'meet': 296,
#  'standard': 297,
#  'nla': 298,
#  'decide': 299,
#  'busts': 300,
#  'period': 301,
#  'expect': 302,
#  'selection': 303,
#  'participate': 304,
#  'czech': 305,
#  'slovakia': 306,
#  'try': 307,
#  'speculation': 308,
#  'participation': 309,
#  'hinder': 310,
#  'chances': 311,
#  'exams': 312,
#  'schedule': 313,
#  'summer': 314,
#  'john': 315,
#  'newfoundland': 316,
#  'labrador': 317,
#  'scorers': 318,
#  'earn': 319,
#  'lose': 320,
#  'relationship': 321,
#  'tennis': 322,
#  'aleksandra': 323,
#  'wozniak': 324,
#  'critique': 325,
#  'twitter': 326,
#  'say': 327,
#  'shot': 328,
#  'major': 329,
#  'economics': 330,
#  'turn': 331,
#  'take': 332,
#  'business': 333,
#  'class': 334,
#  'mcgill': 335,
#  'city': 336,
#  'retirement': 337,
#  'report': 338,
#  'plan': 339}

# %% [markdown]
# [4] 인코딩 : 문장 ==> 수치화 <hr>

# %%
## 인코딩된 문장 리스트 저장용
sentEncodeList = []

## 문장별 토큰을 숫자/정수 인코딩 진행
for sent in sentTKList:
    sentEncode=[]
    for tk in sent:
        sentEncode.append(vocab.get(tk, 0))

    ## 정수 인코딩된 리스트를 추가    
    sentEncodeList.append(sentEncode)
# Out:
# [74, 117, 1, 118, 119, 50, 2, 51]
# [120, 1, 8, 2, 75, 52, 33, 12, 7, 76, 33, 2, 5, 121, 27, 11]
# [34, 13, 35, 9, 4]
# [77, 19, 20, 36, 7, 78, 37, 79, 5, 27, 11, 21, 16, 4, 11, 1, 80, 9, 22, 122, 38, 17, 2, 5, 39, 12, 28]
# [1, 36, 53, 4, 123, 12, 2, 5, 14, 40, 81, 2, 5, 6, 53, 41, 54, 42, 124, 14]
# [1, 52, 125, 82, 43, 55, 83, 2, 5, 56, 8, 6, 84]
# [81, 6, 43, 5, 126, 2]
# [8, 85, 86, 23, 24, 57, 44, 45, 17, 50, 2, 87, 127, 24, 128, 129, 44]
# [1, 58, 13, 130, 59, 88, 131, 2, 60]
# [89, 1, 132, 90, 91, 1, 133, 92, 9, 90, 1, 134, 135, 136, 137, 45, 138, 9, 139, 140, 141, 142, 143, 144, 145, 9, 146]
# [91, 147, 148]
# [93, 149, 74, 150, 2]
# [151, 152, 153, 154, 155, 38, 1, 156, 60, 157, 158, 159]
# [160, 8, 161, 2, 23, 94, 2, 95]
# [12, 94, 162, 163, 164, 165, 166, 60, 80, 96, 93, 97, 167, 3, 168, 9]
# [8, 53, 97, 46, 5, 29, 169]
# [1, 35, 170, 38, 17, 2, 5, 39, 13]
# [171, 172, 20, 173, 76, 33, 2, 5, 61, 36, 7, 12, 6, 174, 15, 18, 10]
# [46, 3, 10, 30, 62, 175, 61, 25, 176, 62, 15, 1, 30, 62]
# [177, 178, 7, 61, 37, 5, 27, 11]
# [179, 7, 1, 180, 181, 182, 183, 34, 13, 184, 185, 35, 9, 4, 186, 13]
# [187, 35, 188, 34, 13, 4, 189]
# [190, 191, 4, 192, 1, 193, 194, 195, 196, 197, 198, 199]
# [4, 200, 201, 202, 203, 1, 204, 98, 33, 63, 205, 206, 38, 39, 207, 208, 209, 210, 51, 211, 212, 213, 3, 214]
# [1, 77, 19, 20, 64, 215, 12, 20, 2, 3, 78]
# [11, 19, 46, 3, 15, 18, 10]
# [37, 79, 5, 27, 11, 216, 27, 11]
# [217, 1, 39, 28, 218, 9, 2, 219, 22, 220, 28, 41, 221, 222, 223, 22, 65]
# [99, 1, 21, 16, 4, 224, 225, 26, 3, 64]
# [226, 16, 227, 228, 95, 229, 230, 19, 58, 231, 232]
# [100, 26, 4, 101, 64, 233, 22, 7]
# [66, 10, 6, 22]
# [234, 3, 235, 236, 92, 9, 237, 238, 239, 3, 41, 1, 17, 28, 102]
# [240, 63, 102, 4, 241, 16, 28, 242, 31, 47, 2, 5, 14, 4, 5, 40]
# [1, 103, 104, 47, 30, 10, 243, 25, 244, 245, 3, 246, 247, 248]
# [6, 47, 48, 10, 1, 105, 4, 103, 104, 54, 42]
# [67, 49, 25, 249, 250, 68, 251, 252, 253, 25, 254, 255, 256, 257, 68]
# [1, 258, 259, 7, 9, 31]
# [8, 6, 4, 15, 18, 6, 47, 29, 15, 18, 260, 261, 262, 18, 10]
# [100, 7, 263, 69, 264, 69, 265, 63, 1, 266, 14, 31, 48, 10, 6, 267, 268, 12, 70, 269, 270]
# [69, 7, 1, 71, 31, 32, 4, 106, 72, 271, 14, 272, 273, 1, 11, 274, 16, 4, 275, 3]
# [105, 4, 7, 8, 6, 276, 277, 278, 14, 279, 280]
# [6, 8, 31, 1, 30, 15, 48, 18]
# [1, 59, 281, 4, 72, 41, 54, 42, 65, 282, 283, 284, 34, 13]
# [285, 107, 1, 21, 286, 42, 36, 7, 14, 40, 287, 288, 29, 10, 6]
# [99, 1, 21, 107, 16, 108, 289]
# [109, 290, 291, 108, 292, 71, 3, 40, 293, 294, 295, 3, 296, 297, 16, 21, 43, 55, 83, 2, 5, 56]
# [298, 299, 300, 1, 82, 3, 301, 302, 303, 304, 305]
# [306, 307, 55, 1, 8, 6, 109, 308, 67, 84]
# [309, 110, 310, 311, 12]
# [56, 312, 32, 1, 313, 32, 314, 315, 110, 316, 1, 317, 318]
# [21, 43, 5, 319]
# [66, 7, 29, 25, 6, 320, 321, 65]
# [58, 4, 13, 322, 323, 59, 88, 324, 70, 325]
# [1, 326, 23, 8, 17, 3, 85, 86, 23, 327, 111, 328, 46, 3, 15, 112, 18, 10, 24, 57, 44]
# [1, 113, 329, 17, 3, 45, 17, 50, 2, 87, 32, 106, 3]
# [330, 331, 114, 2, 5, 115, 332, 333, 334, 3, 115, 32, 8, 6, 114]
# [1, 20, 335, 336, 70, 26]
# [113, 337, 26, 11, 96, 338, 339, 340, 341, 26]
# [26, 68, 1, 37, 72, 45, 22]
# [24, 73, 116, 1, 342, 67, 49]
# [30, 25, 24, 23, 112, 49, 73, 111]
# [48, 49, 57, 44, 73, 24, 343, 116]
# [66, 23, 15, 10, 6, 3, 29]
# [89, 1, 344, 345, 51, 346, 347, 75]
# [1, 71, 14, 7, 348, 98, 349, 350, 1, 351, 352]
# [19, 1, 353, 354]
# [355, 356, 357, 358, 359, 20, 9, 52, 360]
# [101, 361, 362, 363, 364, 19, 11]
