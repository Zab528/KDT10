# %% [markdown]
# #### 【 이미지 분류 모델을 위한 준비 】
#
# - 데이터 준비 : 수집된 데이터 ==> 하나의 데이터로 저장
# - scikit-learn
#     * 피쳐 데이터 : 2D ==> 이미지 파일 1개 ==> 1개 행 데이터. 픽셀이 컬럼이 됨!
#     * 타겟 데이터 : 1D ==> 이미지 파일명
#
# - 데이터 즉, 피쳐와 타겟 => csv, json, xlsx, ... 저장

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비 <hr>

# %%
## 모듈 로딩
import cv2
import pandas as pd
import os
