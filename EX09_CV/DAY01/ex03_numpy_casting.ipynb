# %% [markdown]
# #### 【 Numpy - 자료형 변환/형변환/캐스팅 】
#
# - 묵시적 형변환 : 작은 데이터 타입 => 큰 데이터 타입
#     * 시스템에서 자동 진행
# - 명시적 형변환 : 큰 데이터 타입 => 작은 데이터 타입
#     * 개발자가 진행. 데이터 손실 발생
#     * 일반적으로 형변환 의미가 명시적 형변환

# %%
## 모듈 로딩
import numpy as np          ## 이밎 데이터 저장 관련 모듈
import cv2                  ## opencv 패키지

# %% [markdown]
# - 임의의 데이터 생성 및 형변환 <hr>

# %%
## 임의의 데이터 ndarray 객체 생성
a = np.arange(11,21,3)
print(a.shape, a.dtype, a, sep='\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 ## 임의의 데이터 ndarray 객체 생성
# ----> 2 a = np.arange(11,21,3)
#       3 print(a.shape, a.dtype, a, sep='\n')
#
# NameError: name 'np' is not defined

# %%
## ==============================================
## Image ==> 로딩 : ndarray 데이터
## ==============================================
## 이미지 파일
IMG_FILE = '../Data/Image/blackpink.jpg'

## 이미지 데이터 로딩 : cv2.imread(이미지파일경로_문자열)
imgNP = cv2.imread(IMG_FILE)

## 이미지 로우 데이터 정보 출력
print(f'이미지 로우 데이터 정보 => {imgNP.shape} , {imgNP.ndim}D차원')
# Out:
# 이미지 로우 데이터 정보 => (704, 1199, 3) , 3D차원

# %% [markdown]
# - 이미지와 동일 형태/타입의 ndarray 객체 생성 <hr>

# %%
a = np.empty_like(imgNP)
b = np.zeros_like(imgNP)
c = np.ones_like(imgNP)
d = np.full_like(imgNP, 255)
