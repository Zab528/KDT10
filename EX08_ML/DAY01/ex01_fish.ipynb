# %% [markdown]
# ##### 【 ML - 생선 분류 모델 만들기 1 】
#
# - 주__제 : 2개 종류 생선 분류 모델 만들기
# - 데이터 : ../Data/fish.csv
# - 피쳐들 : 길이와 무게. 실수형
# - 타__겟 : 생선종류
# - 학습종류: 지도학습 -> 분류
# - 학습방법: 다양한 분류 알고리즘들 => KNN 최근접이웃알고리즘
