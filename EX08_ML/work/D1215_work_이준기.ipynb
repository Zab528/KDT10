# %% [markdown]
# ### [2025_1215]_자전거 대여 수요_ 주택 가격 예측
# - 자전거 대여 예측    p362
# - 고급 주택 가격 예측 p375

# %% [markdown]
# ### 자전거 대여 수요 예측

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
